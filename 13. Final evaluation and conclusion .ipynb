# %% [markdown]
# ### Final Evaluation:
#
# I will try the last 4 iterations of the recommendation engine again and use more games to choose one. I will use only the last 4 models as BERT is clearly inferior.

# %%
import pandas as pd
import gc
from fractions import Fraction

# %%
sg_df_clean = pd.read_csv("sg_df_clean.csv")

# %%
gc.collect()
# Out:
# 0

# %%
sg_df_clean["rating_ratio"] = sg_df_clean["rating"]/100
print(sg_df_clean["rating_ratio"])
# Out:
# 0        0.352941
# 1        0.913793
# 2        1.000000
# 3        0.862069
# 4        0.639706
#            ...
# 72366    0.808989
# 72367    0.681199
# 72368    1.000000
# 72369    1.000000
# 72370    0.666667
# Name: rating_ratio, Length: 72371, dtype: float64

# %%
c = sg_df_clean["rating_ratio"].mean()
m= sg_df_clean["user_reviews"].median()

# %%
def weighted_game_score(x, c=c, m=m):
    r = x["rating_ratio"] #I am taking the rating_ratio for each game (row) and storing it as variable r
    n = x["user_reviews"]#I am taking the user_reviews for each game (row) and storing it as variable n
    return ((n*r) / (n+m) + (m*c) / (n+m))

# %%
sg_df_clean["game_score"] = sg_df_clean.apply(weighted_game_score, axis=1)

# %%
sg_df_clean[["name","game_score"]].sample(20)
# Out:
#                                                     name  game_score
# 49496                            The Blueness of a Wound    0.749422
# 62932                              The Symbiant Re:Union    0.919218
# 33779                              Fantastic Contraption    0.777542
# 52431                                     Darkened Glory    0.794876
# 57784                       Merchant of the Six Kingdoms    0.854428
# 50157                                          Gun Witch    0.901207
# 22117                      Time Of Special Team(T.O.S.T)    0.703967
# 62049               Choice Clash: What Would You Rather?    0.737490
# 39269                               Zombie Panic! Source    0.847797
# 36774                               The Wilting Amaranth    0.827636
# 7050                                        Class Escape    0.897913
# 38340                     Mr.Empathy: The Canceled Game.    0.794876
# 55962                                   Dracula Defense!    0.794876
# 27664                                          ARRAYNIUM    0.837182
# 48395                                   The Alpha Device    0.655216
# 9107                                       Delta Horizon    0.749626
# 9076                                            Exostorm    0.721751
# 64161                                         Dreambound    0.863251
# 48332                                Pretty Girls Panic!    0.823140
# 55133  Luna & Monsters Tower Defense -The deprived ma...    0.774364

# %%
def recommend_games(game, sim_matrix, df = sg_df_clean):
    # 1. Find the game's index in the dataframe to use it in the similarity matrix
    try: 
        index = df[df['name'] == game].index[0]
    except IndexError:
        return "The game you typed does not exist in the database. Please make sure the spelling exactly matches the game on steam" #to give an error if the spelling is incorrect
    
    # 2. We create a temp dataframe to modify without changing the original
    temp_df = df.copy()
    
    # 3. We create a new column with the list of cosine similarities for the specified game
    temp_df['similarity'] = sim_matrix[index]
    
    # 4. FILTER (Get top 20 matches)
    # Sort by similarity (Descending)
    # iloc[1:21] grabs the top 20, skipping the game itself (which is the first one since it's the most similar)
    top_similar = temp_df.sort_values('similarity', ascending=False).iloc[1:21]
    
    # 4. RANK (Pick top 5 best quality)
    # Sort the 20 candidates by 'game_score' and pick the top 5
    top_picks = top_similar.sort_values('game_score', ascending=False).head(5)
    
    # 5. Return only the relevant columns
    cols = ['name', 'similarity', 'game_score']
    return top_picks[cols]

# %% [markdown]
# I will create a new function to check recommendations, this time it will have 15 games instead of 5

# %%
def rec_rating(x):
    # Define the list of test games
    test_games = [
        "The Elder Scrolls V: Skyrim Special Edition", "DOOM Eternal", 
        "Hollow Knight", "Hades", "ELDEN RING", "Cyberpunk 2077", "SOMA", 
        "ULTRAKILL", "Sekiro™: Shadows Die Twice - GOTY Edition", "Dota 2", "DUSK", 
        "Borderlands Game of the Year", "CHRONO TRIGGER®", 
        "Divinity: Original Sin 2 - Definitive Edition", "Destiny 2"
    ]
    
    #Loop through and print
    for game in test_games:
        print(f"{game}:")
        # call the function and print the result
        print(recommend_games(game=game, sim_matrix=x))
        
        # This is for formatting
        print("\n" + "="*40 + "\n")

# %% [markdown]
# #### 1: ModernBertEmbed Evaluation:

# %%
Full_cosine_matrix = pd.read_pickle("Full_cosine_matrix_modernbertembed.pkl")

# %%
rec_rating(Full_cosine_matrix)
# Out:
# The Elder Scrolls V: Skyrim Special Edition:
#                                                     name  similarity  \
# 16413  The Elder Scrolls IV: Oblivion® Game of the Ye...    0.532999
# 51296  The Elder Scrolls IV: Oblivion® Game of the Ye...    0.537822
# 5785   The Elder Scrolls III: Morrowind® Game of the ...    0.493882
# 9109                         The Elder Scrolls V: Skyrim    0.616182
# 63572           Horizon Forbidden West™ Complete Edition    0.436708
#
#        game_score
# 16413    0.955539
# 51296    0.955496
# 5785     0.953199
# 9109     0.948258
# 63572    0.938925
#
# ========================================
#
# DOOM Eternal:
#                        name  similarity  game_score
# 3401          Ultimate Doom    0.563734    0.964302
# 33218         Devil Daggers    0.491746    0.955320
# 7623                   DOOM    0.551795    0.952628
# 17204  Warstride Challenges    0.531242    0.917679
# 21004         Dread Templar    0.517306    0.908092
#
# ========================================
#
# Hollow Knight:
#                                          name  similarity  game_score
# 25597    DARK SOULS™: Prepare To Die™ Edition    0.533208    0.914080
# 22417                      Watcher Chronicles    0.534332    0.866833
# 61958                           Kingdom Shell    0.553629    0.865623
# 67425  Toziuha Night: Order of the Alchemists    0.555574    0.865543
# 22235               BLEAK: Welcome to Glimmer    0.616028    0.864556
#
# ========================================
#
# Hades:
#                       name  similarity  game_score
# 64277             Hades II    0.676363    0.946581
# 7180         Skelly Selest    0.565377    0.934654
# 45721        Astral Ascent    0.554585    0.929665
# 51524        Pocket Rogues    0.545629    0.920184
# 37004  Straimium Immortaly    0.547641    0.899923
#
# ========================================
#
# ELDEN RING:
#                                       name  similarity  game_score
# 40444                            Grim Dawn    0.527913    0.934946
# 66710            The Nameless: Slay Dragon    0.498565    0.880310
# 44020                            ELDERBORN    0.504528    0.866990
# 65994            Nine Tereasures of Liuyin    0.508367    0.830418
# 70420  Tails of Iron 2: Whiskers of Winter    0.500320    0.810669
#
# ========================================
#
# Cyberpunk 2077:
#                             name  similarity  game_score
# 45871  The Witcher® 3: Wild Hunt    0.493297    0.961068
# 19992                  Cloudpunk    0.564154    0.891983
# 17288      CYBER EMOJI TALE 2099    0.514724    0.873201
# 19157                        Dex    0.501478    0.871527
# 71087                Agent Dunoz    0.502925    0.832862
#
# ========================================
#
# SOMA:
#                               name  similarity  game_score
# 29647                  DISTRAINT 2    0.480218    0.962347
# 4177   The Coma 2: Vicious Sisters    0.483942    0.960886
# 51661    Amnesia: The Dark Descent    0.510580    0.946939
# 67383                     CAPTURED    0.466322    0.940845
# 57574          Amnesia: The Bunker    0.478703    0.904769
#
# ========================================
#
# ULTRAKILL:
#                                                   name  similarity  game_score
# 17500  Unreal Tournament 2004: Editor's Choice Edition    0.517905    0.974433
# 53559                                      HYPER DEMON    0.542320    0.941629
# 54062                                         Deadlink    0.506958    0.927191
# 59615                                         Voidborn    0.526808    0.910148
# 31977              Marlow Briggs and the Mask of Death    0.510604    0.909644
#
# ========================================
#
# Sekiro™: Shadows Die Twice - GOTY Edition:
#                                        name  similarity  game_score
# 34272                     Blade of Darkness    0.514298    0.949149
# 68244                             Void Sols    0.587148    0.946461
# 25597  DARK SOULS™: Prepare To Die™ Edition    0.559195    0.914080
# 64627                             Nine Sols    0.505876    0.899565
# 34972                        DARK SOULS™ II    0.553746    0.888921
#
# ========================================
#
# Dota 2:
#                              name  similarity  game_score
# 26098             Team Fortress 2    0.477360    0.935611
# 42696         Bloodline Champions    0.511824    0.852211
# 1386   Awesomenauts - the 2D moba    0.503089    0.848222
# 47878               Atlas Reactor    0.476313    0.828626
# 51069                      SMITE®    0.552979    0.800058
#
# ========================================
#
# DUSK:
#                                               name  similarity  game_score
# 52484  Unreal Tournament: Game of the Year Edition    0.496714    0.969576
# 35347                   DUSK '82: ULTIMATE EDITION    0.539435    0.965851
# 27674                                    AMID EVIL    0.597534    0.957286
# 36945                             Nightmare Reaper    0.525659    0.941658
# 13944                              Hedon Bloodrite    0.511709    0.926653
#
# ========================================
#
# Borderlands Game of the Year:
#                                        name  similarity  game_score
# 27524                         Borderlands 2    0.596108    0.937236
# 26977                              Warframe    0.589881    0.901737
# 27187                         Serious Sam 2    0.541799    0.896747
# 11386                      Shadow Warrior 2    0.554884    0.876779
# 4479   Joint Operations: Combined Arms Gold    0.548357    0.876467
#
# ========================================
#
# CHRONO TRIGGER®:
#                                                     name  similarity  \
# 44773         The Legend of Heroes: Trails of Cold Steel    0.578556
# 4110   DRAGON QUEST® XI S: Echoes of an Elusive Age™ ...    0.570338
# 33537    The Legend of Heroes: Trails in the Sky the 3rd    0.584649
# 165        The Legend of Heroes: Trails of Cold Steel II    0.579379
# 10346                                   FINAL FANTASY IX    0.588351
#
#        game_score
# 44773    0.951367
# 4110     0.944891
# 33537    0.944609
# 165      0.942617
# 10346    0.941282
#
# ========================================
#
# Divinity: Original Sin 2 - Definitive Edition:
#                                             name  similarity  game_score
# 5719            Divinity: Original Sin (Classic)    0.612522    0.917095
# 59568                            Untamed Tactics    0.592635    0.909439
# 31229  Divinity: Original Sin - Enhanced Edition    0.622527    0.902199
# 40869               Age of Fear: The Undead King    0.604442    0.884476
# 40646                   Guile & Glory: Firstborn    0.649851    0.878035
#
# ========================================
#
# Destiny 2:
#                                name  similarity  game_score
# 18896            Grapple Tournament    0.509705    0.915046
# 58846  Borderlands Game of the Year    0.520679    0.906128
# 26977                      Warframe    0.594996    0.901737
# 13617                  Guardians VR    0.525961    0.883192
# 57731       Gemini: Binary Conflict    0.558202    0.863251
#
# ========================================

# %%
modernbert_score = (5 + 5 + 4 + 5 + 3 + 3 + 3 + 4 + 4 + 3 + 4 + 4 + 5 + 5 + 3) / (15*5)
modernbert_score
# Out:
# 0.8

# %%
del Full_cosine_matrix
gc.collect()
# Out:
# 0

# %% [markdown]
# #### 2: EmbeddingGemma Evaluation:

# %%
Full_cosine_matrix = pd.read_pickle("Full_cosine_matrix_EmbeddingGemma.pkl")

# %%
rec_rating(Full_cosine_matrix)
# Out:
# The Elder Scrolls V: Skyrim Special Edition:
#                                                     name  similarity  \
# 16413  The Elder Scrolls IV: Oblivion® Game of the Ye...    0.507183
# 51296  The Elder Scrolls IV: Oblivion® Game of the Ye...    0.499036
# 5785   The Elder Scrolls III: Morrowind® Game of the ...    0.439858
# 9109                         The Elder Scrolls V: Skyrim    0.638590
# 3765                                Sid Meier's Pirates!    0.390450
#
#        game_score
# 16413    0.955539
# 51296    0.955496
# 5785     0.953199
# 9109     0.948258
# 3765     0.941963
#
# ========================================
#
# DOOM Eternal:
#                 name  similarity  game_score
# 3401   Ultimate Doom    0.530816    0.964302
# 33218  Devil Daggers    0.464657    0.955320
# 7623            DOOM    0.534766    0.952628
# 23005        DOOM II    0.470500    0.948779
# 53559    HYPER DEMON    0.466565    0.941629
#
# ========================================
#
# Hollow Knight:
#                                 name  similarity  game_score
# 13307  Shovel Knight: Treasure Trove    0.468102    0.962854
# 68244                      Void Sols    0.483538    0.946461
# 58738                  Blasphemous 2    0.471155    0.934871
# 16903                    Blasphemous    0.471990    0.902400
# 61958                  Kingdom Shell    0.506234    0.865623
#
# ========================================
#
# Hades:
#                    name  similarity  game_score
# 32890  Space Gladiators    0.528257    0.955074
# 64277          Hades II    0.625480    0.946581
# 45721     Astral Ascent    0.519241    0.929665
# 51524     Pocket Rogues    0.509699    0.920184
# 60658    Death Must Die    0.510783    0.919162
#
# ========================================
#
# ELDEN RING:
#                                            name  similarity  game_score
# 40444                                 Grim Dawn    0.509290    0.934946
# 25597      DARK SOULS™: Prepare To Die™ Edition    0.509603    0.914080
# 34330                   DARK SOULS™: REMASTERED    0.511880    0.890202
# 44020                                 ELDERBORN    0.494521    0.866990
# 36336  DARK SOULS™ II: Scholar of the First Sin    0.505329    0.848628
#
# ========================================
#
# Cyberpunk 2077:
#                             name  similarity  game_score
# 870           Fallout: New Vegas    0.458906    0.964670
# 45871  The Witcher® 3: Wild Hunt    0.504212    0.961068
# 19992                  Cloudpunk    0.488424    0.891983
# 60922  Cyber Knights: Flashpoint    0.476601    0.888551
# 17288      CYBER EMOJI TALE 2099    0.480193    0.873201
#
# ========================================
#
# SOMA:
#                             name  similarity  game_score
# 66921               Mouthwashing    0.454016    0.966996
# 33048              In Sound Mind    0.456317    0.948026
# 51661  Amnesia: The Dark Descent    0.505914    0.946939
# 2079                   Dark Echo    0.476336    0.923613
# 64811       Still Wakes the Deep    0.503851    0.901983
#
# ========================================
#
# ULTRAKILL:
#                                                   name  similarity  game_score
# 17500  Unreal Tournament 2004: Editor's Choice Edition    0.465167    0.974433
# 53559                                      HYPER DEMON    0.535356    0.941629
# 54062                                         Deadlink    0.488312    0.927191
# 59615                                         Voidborn    0.494965    0.910148
# 21004                                    Dread Templar    0.467773    0.908092
#
# ========================================
#
# Sekiro™: Shadows Die Twice - GOTY Edition:
#                                        name  similarity  game_score
# 68244                             Void Sols    0.513460    0.946461
# 25597  DARK SOULS™: Prepare To Die™ Edition    0.491294    0.914080
# 27956                            ELDEN RING    0.454760    0.899930
# 34972                        DARK SOULS™ II    0.465400    0.888921
# 52829                  Last Night of Winter    0.455552    0.884289
#
# ========================================
#
# Dota 2:
#                                           name  similarity  game_score
# 26098                          Team Fortress 2    0.470229    0.935611
# 33581  Legion TD 2 - Multiplayer Tower Defense    0.417143    0.856233
# 42696                      Bloodline Champions    0.454148    0.852211
# 1386                Awesomenauts - the 2D moba    0.460641    0.848222
# 32986                          Dota Underlords    0.419690    0.825598
#
# ========================================
#
# DUSK:
#                              name  similarity  game_score
# 35347  DUSK '82: ULTIMATE EDITION    0.470625    0.965851
# 27674                   AMID EVIL    0.584763    0.957286
# 36945            Nightmare Reaper    0.507961    0.941658
# 47675                      Shrine    0.455867    0.926539
# 21004               Dread Templar    0.480459    0.908092
#
# ========================================
#
# Borderlands Game of the Year:
#                                         name  similarity  game_score
# 27524                          Borderlands 2    0.575820    0.937236
# 26977                               Warframe    0.490020    0.901737
# 27187                          Serious Sam 2    0.495883    0.896747
# 11386                       Shadow Warrior 2    0.495137    0.876779
# 27062  Borderlands Game of the Year Enhanced    0.748391    0.861095
#
# ========================================
#
# CHRONO TRIGGER®:
#                                                     name  similarity  \
# 9286          The Legend of Heroes: Trails in the Sky SC    0.442028
# 4110   DRAGON QUEST® XI S: Echoes of an Elusive Age™ ...    0.446759
# 165        The Legend of Heroes: Trails of Cold Steel II    0.451185
# 10346                                   FINAL FANTASY IX    0.467060
# 51002                              Time Break Chronicles    0.464087
#
#        game_score
# 9286     0.977352
# 4110     0.944891
# 165      0.942617
# 10346    0.941282
# 51002    0.915348
#
# ========================================
#
# Divinity: Original Sin 2 - Definitive Edition:
#                                             name  similarity  game_score
# 31229  Divinity: Original Sin - Enhanced Edition    0.555828    0.902199
# 40869               Age of Fear: The Undead King    0.556911    0.884476
# 40646                   Guile & Glory: Firstborn    0.613674    0.878035
# 70422                             Those Who Rule    0.574042    0.876429
# 64694                                   Arhaekon    0.543221    0.867273
#
# ========================================
#
# Destiny 2:
#                                name  similarity  game_score
# 43224                  Titanfall® 2    0.460556    0.946966
# 58846  Borderlands Game of the Year    0.468185    0.906128
# 26977                      Warframe    0.524662    0.901737
# 11386              Shadow Warrior 2    0.453961    0.876779
# 36354                  EVERSPACE™ 2    0.433529    0.874469
#
# ========================================

# %%
EmbeddingGemma_score = (4 + 5 + 4 + 5 + 4 + 5 + 4 + 5 + 3 + 2 + 4 + 5 + 5 + 5 + 4) / (15*5)
EmbeddingGemma_score
# Out:
# 0.8533333333333334

# %%
del Full_cosine_matrix
gc.collect()
# Out:
# 0

# %% [markdown]
# #### 3: Qwen3-embedding-0.6B V1 Evaluation:

# %%
Full_cosine_matrix = pd.read_pickle("Full_cosine_matrix_Qwen-3-6B.pkl")

# %%
rec_rating(Full_cosine_matrix)
# Out:
# The Elder Scrolls V: Skyrim Special Edition:
#                                                     name  similarity  \
# 16413  The Elder Scrolls IV: Oblivion® Game of the Ye...    0.569550
# 51296  The Elder Scrolls IV: Oblivion® Game of the Ye...    0.554443
# 5785   The Elder Scrolls III: Morrowind® Game of the ...    0.544408
# 9109                         The Elder Scrolls V: Skyrim    0.577546
# 63572           Horizon Forbidden West™ Complete Edition    0.559197
#
#        game_score
# 16413    0.955539
# 51296    0.955496
# 5785     0.953199
# 9109     0.948258
# 63572    0.938925
#
# ========================================
#
# DOOM Eternal:
#                      name  similarity  game_score
# 12387                DUSK    0.574517    0.978824
# 48612      Shadow Warrior    0.555321    0.925725
# 60722       Missiles Away    0.578699    0.895053
# 18318  Serious Sam 3: BFE    0.562023    0.884007
# 11386    Shadow Warrior 2    0.558709    0.876779
#
# ========================================
#
# Hollow Knight:
#                               name  similarity  game_score
# 58738                Blasphemous 2    0.605772    0.934871
# 2014      Voodoo Vince: Remastered    0.585350    0.915410
# 31391  Silver Axe - The Honest Elf    0.635765    0.909746
# 35409     Shantae: Half-Genie Hero    0.579690    0.903891
# 64627                    Nine Sols    0.600673    0.899565
#
# ========================================
#
# Hades:
#                       name  similarity  game_score
# 64277             Hades II    0.678321    0.946581
# 45721        Astral Ascent    0.635234    0.929665
# 51524        Pocket Rogues    0.616346    0.920184
# 42769          Dreamscaper    0.608986    0.905251
# 37004  Straimium Immortaly    0.654371    0.899923
#
# ========================================
#
# ELDEN RING:
#                                        name  similarity  game_score
# 40444                             Grim Dawn    0.599717    0.934946
# 5719       Divinity: Original Sin (Classic)    0.583123    0.917095
# 25597  DARK SOULS™: Prepare To Die™ Edition    0.612766    0.914080
# 51396                         Dark Bestiary    0.586273    0.907222
# 34972                        DARK SOULS™ II    0.578567    0.888921
#
# ========================================
#
# Cyberpunk 2077:
#                                       name  similarity  game_score
# 45871            The Witcher® 3: Wild Hunt    0.620689    0.961068
# 19992                            Cloudpunk    0.600656    0.891983
# 67643                       Din's Champion    0.598039    0.889519
# 32923            The Elder Scrolls® Online    0.604200    0.820535
# 41948  Fallout 3: Game of the Year Edition    0.596394    0.790474
#
# ========================================
#
# SOMA:
#                           name  similarity  game_score
# 66921             Mouthwashing    0.617240    0.966996
# 56978       Chernobyl: Origins    0.615100    0.904953
# 53420        SCP: Secret Files    0.601107    0.899264
# 29272  Dark Fracture: Prologue    0.589955    0.857065
# 13892              The Station    0.615313    0.855493
#
# ========================================
#
# ULTRAKILL:
#                                       name  similarity  game_score
# 54062                             Deadlink    0.591382    0.927191
# 59615                             Voidborn    0.587317    0.910148
# 31977  Marlow Briggs and the Mask of Death    0.584693    0.909644
# 57423                      Magenta Horizon    0.617962    0.904953
# 40242                            Self Shot    0.623251    0.857868
#
# ========================================
#
# Sekiro™: Shadows Die Twice - GOTY Edition:
#                                        name  similarity  game_score
# 34272                     Blade of Darkness    0.560897    0.949149
# 68244                             Void Sols    0.595688    0.946461
# 71514           The First Berserker: Khazan    0.622449    0.917833
# 25597  DARK SOULS™: Prepare To Die™ Edition    0.575694    0.914080
# 56217             Clash: Artifacts of Chaos    0.577545    0.907898
#
# ========================================
#
# Dota 2:
#                       name  similarity  game_score
# 34480             MageQuit    0.588573    0.955260
# 26098      Team Fortress 2    0.579966    0.935611
# 19871            Teeworlds    0.577553    0.888250
# 626          Apex Legends™    0.599691    0.861843
# 42696  Bloodline Champions    0.606198    0.852211
#
# ========================================
#
# DUSK:
#                 name  similarity  game_score
# 18848    The Citadel    0.595984    0.938805
# 47675         Shrine    0.585096    0.926539
# 51995   DOOM Eternal    0.574517    0.910742
# 21004  Dread Templar    0.632188    0.908092
# 24024         CARNAL    0.571863    0.896582
#
# ========================================
#
# Borderlands Game of the Year:
#                                         name  similarity  game_score
# 27187                          Serious Sam 2    0.636018    0.896747
# 18318                     Serious Sam 3: BFE    0.616417    0.884007
# 11386                       Shadow Warrior 2    0.655454    0.876779
# 27062  Borderlands Game of the Year Enhanced    0.682714    0.861095
# 60811                       Anger Of Peace 5    0.580685    0.854428
#
# ========================================
#
# CHRONO TRIGGER®:
#                                                   name  similarity  game_score
# 17846                      Life is Strange - Episode 1    0.551270    0.961253
# 33537  The Legend of Heroes: Trails in the Sky the 3rd    0.570802    0.944609
# 165      The Legend of Heroes: Trails of Cold Steel II    0.575393    0.942617
# 18313                                        Einlanzer    0.559907    0.911882
# 57301          CONVERGENCE: A League of Legends Story™    0.558213    0.897669
#
# ========================================
#
# Divinity: Original Sin 2 - Definitive Edition:
#                                name  similarity  game_score
# 828               Voidspire Tactics    0.663453    0.954490
# 63361                Dawnsbury Days    0.658246    0.943249
# 34379    Telepath Tactics Liberated    0.682220    0.899850
# 40869  Age of Fear: The Undead King    0.678787    0.884476
# 70422                Those Who Rule    0.667505    0.876429
#
# ========================================
#
# Destiny 2:
#                           name  similarity  game_score
# 26977                 Warframe    0.659878    0.901737
# 57731  Gemini: Binary Conflict    0.619869    0.863251
# 626              Apex Legends™    0.600003    0.861843
# 16840                Paladins®    0.601867    0.855371
# 16434            Borderlands 3    0.646388    0.843304
#
# ========================================

# %%
Qwen3_V1_score = (5 + 5 + 4 + 5 + 3 + 3 + 4 + 3 + 5 + 2 + 4 + 5 + 3 + 3 + 4) / (15*5)
Qwen3_V1_score
# Out:
# 0.7733333333333333

# %%
del Full_cosine_matrix
gc.collect()
# Out:
# 0

# %% [markdown]
# #### 4: Qwen3-embedding-0.6B V2 Evaluation:

# %%
Full_cosine_matrix = pd.read_pickle("Full_cosine_matrix_Qwen-3-6B-V2.pkl")

# %%
rec_rating(Full_cosine_matrix)
# Out:
# The Elder Scrolls V: Skyrim Special Edition:
#                                                     name  similarity  \
# 5785   The Elder Scrolls III: Morrowind® Game of the ...    0.600299
# 9109                         The Elder Scrolls V: Skyrim    0.693637
# 3765                                Sid Meier's Pirates!    0.619610
# 63572           Horizon Forbidden West™ Complete Edition    0.596526
# 32158                   Middle-earth™: Shadow of Mordor™    0.593767
#
#        game_score
# 5785     0.953199
# 9109     0.948258
# 3765     0.941963
# 63572    0.938925
# 32158    0.922377
#
# ========================================
#
# DOOM Eternal:
#                 name  similarity  game_score
# 3401   Ultimate Doom    0.609788    0.964302
# 57770       Trepang2    0.599833    0.954439
# 7623            DOOM    0.603032    0.952628
# 15523        DOOM 64    0.594878    0.938437
# 29452      Shrine II    0.589017    0.930044
#
# ========================================
#
# Hollow Knight:
#                                   name  similarity  game_score
# 31391      Silver Axe - The Honest Elf    0.606743    0.909746
# 35409         Shantae: Half-Genie Hero    0.559532    0.903891
# 64627                        Nine Sols    0.556406    0.899565
# 42209               WarriOrb: Prologue    0.608180    0.881218
# 23321  Under The Ghost Mountain - 鬼山之下    0.556390    0.871065
#
# ========================================
#
# Hades:
#                          name  similarity  game_score
# 64277                Hades II    0.637432    0.946581
# 45721           Astral Ascent    0.614859    0.929665
# 51524           Pocket Rogues    0.587709    0.920184
# 37004     Straimium Immortaly    0.626600    0.899923
# 63410  Penny Blood: Hellbound    0.595094    0.892554
#
# ========================================
#
# ELDEN RING:
#                                        name  similarity  game_score
# 25597  DARK SOULS™: Prepare To Die™ Edition    0.575129    0.914080
# 53981           The Last Hero of Nostalgaia    0.581548    0.907562
# 34194                            TWO MONTHS    0.586223    0.895986
# 69534                             FOUNTAINS    0.583788    0.893601
# 34330               DARK SOULS™: REMASTERED    0.583248    0.890202
#
# ========================================
#
# Cyberpunk 2077:
#                                               name  similarity  game_score
# 45871                    The Witcher® 3: Wild Hunt    0.599781    0.961068
# 56188             The Black Grimoire: Cursebreaker    0.600871    0.911085
# 41072  The Elder Scrolls V: Skyrim Special Edition    0.597102    0.909533
# 984                                        Gedonia    0.599430    0.900852
# 19992                                    Cloudpunk    0.657604    0.891983
#
# ========================================
#
# SOMA:
#                                 name  similarity  game_score
# 66921                   Mouthwashing    0.637440    0.966996
# 2079                       Dark Echo    0.603228    0.923613
# 64811           Still Wakes the Deep    0.625784    0.901983
# 63579  Midnight Scenes: A Safe Place    0.611788    0.889746
# 36646                  The Whisperer    0.631403    0.851934
#
# ========================================
#
# ULTRAKILL:
#                           name  similarity  game_score
# 54062                 Deadlink    0.652152    0.927191
# 4341             Ratz Instagib    0.660165    0.882921
# 67136  Ash & Adam's GOBSMACKED    0.647903    0.862182
# 40242                Self Shot    0.731357    0.857868
# 57403           Zombie Defense    0.664560    0.844389
#
# ========================================
#
# Sekiro™: Shadows Die Twice - GOTY Edition:
#                               name  similarity  game_score
# 68244                    Void Sols    0.660197    0.946461
# 71514  The First Berserker: Khazan    0.645695    0.917833
# 23298           Endless Boss Fight    0.602253    0.897913
# 53163                   One by One    0.618500    0.874647
# 64763                  EVERCHAINED    0.602915    0.863251
#
# ========================================
#
# Dota 2:
#                              name  similarity  game_score
# 34480                    MageQuit    0.597867    0.955260
# 42696         Bloodline Champions    0.630162    0.852211
# 1386   Awesomenauts - the 2D moba    0.617501    0.848222
# 47878               Atlas Reactor    0.601353    0.828626
# 51069                      SMITE®    0.696762    0.800058
#
# ========================================
#
# DUSK:
#                             name  similarity  game_score
# 36945           Nightmare Reaper    0.619739    0.941658
# 47675                     Shrine    0.602279    0.926539
# 21004              Dread Templar    0.643462    0.908092
# 24024                     CARNAL    0.595759    0.896582
# 9483   The Apogee Throwback Pack    0.648917    0.890436
#
# ========================================
#
# Borderlands Game of the Year:
#                                         name  similarity  game_score
# 26977                               Warframe    0.625796    0.901737
# 27187                          Serious Sam 2    0.646657    0.896747
# 11386                       Shadow Warrior 2    0.658344    0.876779
# 27062  Borderlands Game of the Year Enhanced    0.727101    0.861095
# 27405      Tom Clancy's Rainbow Six® Vegas 2    0.637678    0.849204
#
# ========================================
#
# CHRONO TRIGGER®:
#                                                   name  similarity  game_score
# 7427                                       To the Moon    0.586501    0.964315
# 17846                      Life is Strange - Episode 1    0.573677    0.961253
# 33537  The Legend of Heroes: Trails in the Sky the 3rd    0.581915    0.944609
# 165      The Legend of Heroes: Trails of Cold Steel II    0.588492    0.942617
# 41489                           The Witches' Tea Party    0.576705    0.941327
#
# ========================================
#
# Divinity: Original Sin 2 - Definitive Edition:
#                               name  similarity  game_score
# 34379   Telepath Tactics Liberated    0.694012    0.899850
# 61897     REMORE: INFESTED KINGDOM    0.715932    0.880076
# 40646     Guile & Glory: Firstborn    0.686067    0.878035
# 70422               Those Who Rule    0.721603    0.876429
# 54925  Grey Heritage: Faded Vision    0.691430    0.858978
#
# ========================================
#
# Destiny 2:
#                                name  similarity  game_score
# 58846  Borderlands Game of the Year    0.637335    0.906128
# 26977                      Warframe    0.639427    0.901737
# 16434                 Borderlands 3    0.645829    0.843304
# 59614               Galaxy Kingdoms    0.636621    0.827728
# 18211                      Traveler    0.639767    0.826434
#
# ========================================

# %%
Qwen3_V2_score = (3 + 5 + 5 + 5 + 4 + 3 + 2 + 3 + 3 + 4 + 4 + 5 + 2 + 4 + 3) / (15*5)
Qwen3_V2_score
# Out:
# 0.7333333333333333

# %%
del Full_cosine_matrix
gc.collect()
# Out:
# 0

# %% [markdown]
# #### 5: Qwen3-embedding-0.6B V3 Evaluation:

# %%
Full_cosine_matrix = pd.read_pickle("Full_cosine_matrix_Qwen-3-6B-V3.pkl")

# %%
rec_rating(Full_cosine_matrix)
# Out:
# The Elder Scrolls V: Skyrim Special Edition:
#                                                     name  similarity  \
# 5785   The Elder Scrolls III: Morrowind® Game of the ...    0.411369
# 9109                         The Elder Scrolls V: Skyrim    0.514083
# 4360                                         RuneScape ®    0.410125
# 15646                       Mount & Blade II: Bannerlord    0.407139
# 38656                                             ADONIS    0.409396
#
#        game_score
# 5785     0.953199
# 9109     0.948258
# 4360     0.879675
# 15646    0.876779
# 38656    0.848541
#
# ========================================
#
# DOOM Eternal:
#                                                     name  similarity  \
# 3401                                       Ultimate Doom    0.463865
# 7623                                                DOOM    0.423732
# 53559                                        HYPER DEMON    0.422673
# 15523                                            DOOM 64    0.421294
# 42470  Demon Slayer -Kimetsu no Yaiba- The Hinokami C...    0.420670
#
#        game_score
# 3401     0.964302
# 7623     0.952628
# 53559    0.941629
# 15523    0.938437
# 42470    0.882658
#
# ========================================
#
# Hollow Knight:
#                                          name  similarity  game_score
# 47026     UNDER NIGHT IN-BIRTH Exe:Late[cl-r]    0.452457    0.939053
# 31391             Silver Axe - The Honest Elf    0.520533    0.909746
# 64627                               Nine Sols    0.448620    0.899565
# 42209                      WarriOrb: Prologue    0.463030    0.881218
# 67425  Toziuha Night: Order of the Alchemists    0.487804    0.865543
#
# ========================================
#
# Hades:
#                       name  similarity  game_score
# 32890     Space Gladiators    0.446134    0.955074
# 64277             Hades II    0.540339    0.946581
# 7180         Skelly Selest    0.451848    0.934654
# 45721        Astral Ascent    0.466117    0.929665
# 37004  Straimium Immortaly    0.487496    0.899923
#
# ========================================
#
# ELDEN RING:
#                                        name  similarity  game_score
# 33665  ENDER LILIES: Quietus of the Knights    0.445786    0.953171
# 25597  DARK SOULS™: Prepare To Die™ Edition    0.448765    0.914080
# 34330               DARK SOULS™: REMASTERED    0.452755    0.890202
# 2906                            Arx Fatalis    0.445735    0.872367
# 44020                             ELDERBORN    0.458263    0.866990
#
# ========================================
#
# Cyberpunk 2077:
#                                               name  similarity  game_score
# 41072  The Elder Scrolls V: Skyrim Special Edition    0.428977    0.909533
# 19992                                    Cloudpunk    0.489654    0.891983
# 4360                                   RuneScape ®    0.432437    0.879675
# 19157                                          Dex    0.428031    0.871527
# 68126                                 Seven Cities    0.439423    0.833007
#
# ========================================
#
# SOMA:
#                             name  similarity  game_score
# 66921               Mouthwashing    0.468200    0.966996
# 51661  Amnesia: The Dark Descent    0.448811    0.946939
# 48225                       Röki    0.450636    0.917637
# 64811       Still Wakes the Deep    0.481352    0.901983
# 53420          SCP: Secret Files    0.474003    0.899264
#
# ========================================
#
# ULTRAKILL:
#                                                   name  similarity  game_score
# 17500  Unreal Tournament 2004: Editor's Choice Edition    0.430986    0.974433
# 53559                                      HYPER DEMON    0.442544    0.941629
# 54062                                         Deadlink    0.420894    0.927191
# 59615                                         Voidborn    0.412078    0.910148
# 31977              Marlow Briggs and the Mask of Death    0.410378    0.909644
#
# ========================================
#
# Sekiro™: Shadows Die Twice - GOTY Edition:
#                                        name  similarity  game_score
# 68244                             Void Sols    0.512468    0.946461
# 71514           The First Berserker: Khazan    0.453982    0.917833
# 25597  DARK SOULS™: Prepare To Die™ Edition    0.445591    0.914080
# 64627                             Nine Sols    0.446122    0.899565
# 34972                        DARK SOULS™ II    0.454567    0.888921
#
# ========================================
#
# Dota 2:
#                              name  similarity  game_score
# 34480                    MageQuit    0.446123    0.955260
# 42696         Bloodline Champions    0.481581    0.852211
# 1386   Awesomenauts - the 2D moba    0.474842    0.848222
# 47878               Atlas Reactor    0.462422    0.828626
# 51069                      SMITE®    0.545522    0.800058
#
# ========================================
#
# DUSK:
#                   name  similarity  game_score
# 27674        AMID EVIL    0.431682    0.957286
# 53559      HYPER DEMON    0.422268    0.941629
# 13944  Hedon Bloodrite    0.420485    0.926653
# 47675           Shrine    0.420882    0.926539
# 51995     DOOM Eternal    0.420914    0.910742
#
# ========================================
#
# Borderlands Game of the Year:
#                                         name  similarity  game_score
# 27524                          Borderlands 2    0.464761    0.937236
# 26977                               Warframe    0.474996    0.901737
# 11386                       Shadow Warrior 2    0.534062    0.876779
# 4479    Joint Operations: Combined Arms Gold    0.473303    0.876467
# 27062  Borderlands Game of the Year Enhanced    0.592301    0.861095
#
# ========================================
#
# CHRONO TRIGGER®:
#                                                   name  similarity  game_score
# 7427                                       To the Moon    0.428048    0.964315
# 17846                      Life is Strange - Episode 1    0.406730    0.961253
# 44773       The Legend of Heroes: Trails of Cold Steel    0.413779    0.951367
# 33537  The Legend of Heroes: Trails in the Sky the 3rd    0.444378    0.944609
# 165      The Legend of Heroes: Trails of Cold Steel II    0.441360    0.942617
#
# ========================================
#
# Divinity: Original Sin 2 - Definitive Edition:
#                                name  similarity  game_score
# 34379    Telepath Tactics Liberated    0.502101    0.899850
# 3027                The Banner Saga    0.479801    0.891208
# 40869  Age of Fear: The Undead King    0.487665    0.884476
# 40646      Guile & Glory: Firstborn    0.496827    0.878035
# 70422                Those Who Rule    0.512713    0.876429
#
# ========================================
#
# Destiny 2:
#                           name  similarity  game_score
# 26977                 Warframe    0.437918    0.901737
# 11386         Shadow Warrior 2    0.442540    0.876779
# 57731  Gemini: Binary Conflict    0.460590    0.863251
# 15997        Endless Firepower    0.457819    0.819091
# 51854             Rebel Forces    0.434374    0.816754
#
# ========================================

# %%
Qwen3_V3_score = (4 + 4 + 4 + 5 + 2 + 4 + 4 + 5 + 4 + 5 + 4 + 3 + 5 + 3) / (15*5)
Qwen3_V3_score
# Out:
# 0.7466666666666667

# %% [markdown]
# ### Conclusion:
#
# | Model | Score |
# | :--- | :--- |
# | EmbeddingGemma | 0.853 |
# | ModernBertEmbed | 0.8 |
# | Qwen3 V1 | 0.773 |
# | Qwen3 V3 | 0.7467 |
# | Qwen3 V2 | 0.733 |
#
# EmbeddingGemma managed to recommend much better games with modernbert following right behind it. Qwen3 models however fell short with a lot of recommendations being completely differentated.
#
# Possible reasons include:
#
# 1. The length of the documents: The "about the game" section is not a lengthy document that requires a lot of context, which is what qwen3-embed 0.6B excels at.
#
# 2. EmbeddingGemma is bidirectional while qwen3-embed reads text from left to right only. It could miss context that EmbeddingGemma would capture. MoidernBertEmbed is also bidirectional which could explain the better results than qwen3-embed.
#
# 3. The number of tokens, due to ram limitations, qwen3-embed cannot use 32k tokens. I used 512 tokens for all models.
#
# Overall, the EmbeddingGemma recommendations engine is very viable as a tool for steam itself or third party sites. It could help users looking for hidden gems especially if their interested in niche genres. This would help increase the revenue for developers who struggle with visibility, help steam diversify the sources of revenue and help users find games that match their interest.
#
# ##### Limitations:
#
# 1. The project relies a lot on user reviews which can be unreliable. For example, a very well regarded game critically could be given a low user score due to sociopolitics or bugs. The opposite could also be true as niche games may have a high percentage of positive reviews which may not reflect the quality of the game.
#
# 2. "about the game" is an arbitrary way to compare games since it is a free form way for the developers to describe their game. Very similar games may not have the same description.
#
# 3. The model uses texts only to find similar games, when in reality video games are more complex and video data would probably reflect the game better.
#
# 4. Tags are also user defined and may not be the best way to "frame" a game.
#
# 5. Lack of user data, which could be helpful for detecting patterns for similar tastes.
#
# 6. The data is not updated, it is a bit more than a year old.
#
# 7. The recommendations engine is "static" as adding more data would require repeating the whole process.
#
# 8. The scoring system for recommendations is arbitrary as it relies on my subjective opinion of what a good recommendation is. Ideally, it would be tested by users on a larger scale.ated.

# %% [markdown]
# ### References
#
# __Dataset__
#
# 1. https://www.kaggle.com/datasets/fronkongames/steam-games-dataset
#
# __Models__
#
# 1. https://huggingface.co/nomic-ai/modernbert-embed-base
#
# 2. https://huggingface.co/google/embeddinggemma-300m
#
# 3. https://huggingface.co/Qwen/Qwen3-Embedding-0.6B
#
# 4. https://huggingface.co/google-bert/bert-base-uncased
#
# __Libraries__
#
# 1. Pandas
# 2. Numpy
# 3. ast
# 4. gc
# 5. SentenceTransformers
# 6. Matplotlib
# 7. Seaborn
# 8. Transformers
# 9. Langid
# 10. sys
# 11. Pytorch
# 12. scikit-learn
# 13. wordcloud
# 14. huggingface_hub
